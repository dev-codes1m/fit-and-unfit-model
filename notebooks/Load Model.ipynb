# %%
from tensorflow import keras

# %%
a = keras.models.load_model('transfer.h5')

# %%
IMG_SIZE = [224,224]

# %%
from keras.preprocessing import image
img = image.load_img(r"D:\Transfer\train\fit images\img153.jpg",target_size=IMG_SIZE)

# %%
from  keras.preprocessing.image import img_to_array
x = image.img_to_array(img)

# %%
import numpy as np
x = np.expand_dims(x,axis=0)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
k = a.predict(x).round()

# %%
k
# Out:
# array([[1., 0.]], dtype=float32)

# %%
if k[0][0]>k[0][1]:
    print("fit")
else:
    print("unfit")
# Out:
# fit
